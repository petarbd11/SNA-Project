# %% [markdown]
# # 0) Import packages

# %%
#Import packages
import random # random generator
import networkx as nx # network 
import matplotlib.pyplot as plt # drawing
import numpy as np # Matrices
import csv # Reading excel file

# %% [markdown]
# # 1) Introduction

# %% [markdown]
# ## Python

# %% [markdown]
# All programming will be done in python. There is a need to be comfortable with programming to validate the project part of the course.
#
# You can either use an online editor or an offline editor.
#
# The final report should be given as a Jupyter file like this file composed of introduction, a section for each question of the project and a conclusion.
#
# You need to provide some code and also some explanation/analysis.
#
# You also need to indicate your group and the member of the group
#
# Each week, we will introduce the basic functions corresponding to the current chapter. For the project, you need to adapt what we are doing into your own network (by making proper adjustement).

# %% [markdown]
# ## A Key package : Nerworkx

# %% [markdown]
# An extensive documentation can be found at
#
# https://networkx.org/documentation
#
# Aric A. Hagberg, Daniel A. Schult and Pieter J. Swart, “Exploring network structure, dynamics, and function using NetworkX”, in Proceedings of the 7th Python in Science Conference (SciPy2008), Gäel Varoquaux, Travis Vaught, and Jarrod Millman (Eds), (Pasadena, CA USA), pp. 11–15, Aug 2008
#
# The aim is to give you a first look at the main functions in networkx.

# %% [markdown]
# Several general remarks on specificity of python:
#     - the first element in a table/lists/matrix in python has index 0
#     So a list of n elements obtained for example by range(n) goes from 0 to n-1
#
#     - For some objects, there are several natural operations. When this is the case the usual
#     Name_of_function(Name_of_object) will be replaced by Name_of_object.Name_of_function
#
#     - Level in different level of loops is given by the indentation
#
#     - (Personal opinion) Programming is three things :
#         *logic of programming (how to combine objects: loop, condition).
#         *how to make the code work.
#         *knowledge of libraries.

# %% [markdown]
# # 2) Project (week 1)

# %% [markdown]
# a) Pick a social network among the one proposed on luiss.learn
#
# b) Implement it in Python.
#
# c) Draw the graph
#
# d) Compute the number of nodes,edges, average degree and the density. Comment.
#
# Be careful if the network that you have picked is directed or not.

# %% [markdown]
# # 3) Drawing graphs

# %%
# Pick a number between 1 and 1253 and pick the corresponding graph in a list
N=38
G0=nx.graph_atlas(N)

# %%
#Draw the graph

nx.draw(G0,with_labels=True)

# %%
#Create a Erdos-renyi (formql definition week 9) graph using networkx
N=50
p = 0.1
G= nx.erdos_renyi_graph(N,p)

# %%
#draw G

nx.draw(G)

# %% [markdown]
# ### Visualization different layouts

# %% [markdown]
# "Proper graph visualization is hard, and we highly recommend that people visualize their graphs with tools dedicated to that task".
#
# Here is simple visualization, using matplotlib

# %% [markdown]
# https://networkx.org/documentation/stable/reference/drawing.html

# %%
sna_advice=[(32, 38), (32, 41), (38, 5), (38, 10), (38, 38), (38, 26), (38, 32), (6, 19), (7, 36), (36, 33), (36, 39), (36, 41), (33, 36), (33, 39), (33, 41), (39, 42), (24, 24), (24, 39), (42, 34), (18, 39), (26, 20), (26, 41), (31, 17), (31, 14), (31, 8), (31, 12), (30, 9), (30, 30), (40, 0), (40, 33), (40, 1), (40, 15), (40, 28), (40, 38), (40, 32), (15, 41), (28, 42), (28, 34), (22, 42), (22, 39), (37, 42), (37, 16), (37, 25), (37, 37), (37, 41), (37, 23), (43, 42), (43, 36), (43, 37), (43, 39), (43, 34), (43, 27), (43, 21), (43, 41), (43, 23), (34, 42), (27, 42), (35, 42), (35, 25), (35, 18), (35, 39), (35, 34), (35, 41), (29, 17), (29, 14), (29, 13), (44, 2), (44, 42), (44, 4), (44, 28), (44, 16), (44, 36), (44, 25), (44, 29), (44, 43), (44, 20), (44, 19), (44, 40), (44, 11), (44, 27), (44, 21), (44, 41), (3, 30)]
N=44

G=nx.from_edgelist(sna_advice)

# %%
# Simply Nodes on circle
nx.draw_circular(G,with_labels=True)

# %%
#Notice that the previous graph is not directed if we want a directed graph
G=nx.from_edgelist(sna_advice,create_using=nx.DiGraph())

# %%
nx.draw_circular(G,with_labels=True)

# %%
# Let us keep undirected graph for this presentation.
#Alternatively, one can define the position and pas as parameter of the function draw.

G=nx.from_edgelist(sna_advice)

pos=nx.circular_layout(G) # create the position in a circular way
nx.draw(G,pos) # this allows to have different choice for the position

# %%
# Random layout : directly create the position and draw
nx.draw_random(G)

# %%
nx.draw_spring(G)

# %% [markdown]
# # 4) From one representation of a graph to another one

# %% [markdown]
# We have seen in the lessons that there are several ways to define a graph: list of edges and adjacency matrix. It is possible with networkx, to go from one representation to the other one.

# %%
G.nodes
# Out:
# NodeView((32, 38, 41, 5, 10, 26, 6, 19, 7, 36, 33, 39, 42, 24, 34, 18, 20, 31, 17, 14, 8, 12, 30, 9, 40, 0, 1, 15, 28, 22, 37, 16, 25, 23, 43, 27, 21, 35, 29, 13, 44, 2, 4, 11, 3))

# %%
# Notice that it looks like a list. It is not but it still behave like it
type(G.nodes)
# Out:
# networkx.classes.reportviews.NodeView

# %%
G.edges
# Out:
# EdgeView([(32, 38), (32, 41), (32, 40), (38, 5), (38, 10), (38, 38), (38, 26), (38, 40), (41, 36), (41, 33), (41, 26), (41, 15), (41, 37), (41, 43), (41, 35), (41, 44), (26, 20), (6, 19), (19, 44), (7, 36), (36, 33), (36, 39), (36, 43), (36, 44), (33, 39), (33, 40), (39, 42), (39, 24), (39, 18), (39, 22), (39, 43), (39, 35), (42, 34), (42, 28), (42, 22), (42, 37), (42, 43), (42, 27), (42, 35), (42, 44), (24, 24), (34, 28), (34, 43), (34, 35), (18, 35), (20, 44), (31, 17), (31, 14), (31, 8), (31, 12), (17, 29), (14, 29), (30, 9), (30, 30), (30, 3), (40, 0), (40, 1), (40, 15), (40, 28), (40, 44), (28, 44), (37, 16), (37, 25), (37, 37), (37, 23), (37, 43), (16, 44), (25, 35), (25, 44), (23, 43), (43, 27), (43, 21), (43, 44), (27, 44), (21, 44), (29, 13), (29, 44), (44, 2), (44, 4), (44, 11)])

# %% [markdown]
# ### From the graph to the matrix

# %%
A=nx.adjacency_matrix(G0)
print(A)
print(type(A))
# Strange form : Compressed Sparse Row matrix. 
#Since there is a lot of zeros, it is saved in the computer differently to save speed
# Out:
#   (0, 1)	1
#   (0, 4)	1
#   (1, 0)	1
#   (1, 2)	1
#   (2, 1)	1
#   (2, 3)	1
#   (3, 2)	1
#   (3, 4)	1
#   (4, 0)	1
#   (4, 3)	1
# <class 'scipy.sparse.csr.csr_matrix'>

# %% [markdown]
# ### From the graph to an edge list

# %%
G0.edges
# Out:
# EdgeView([(0, 1), (0, 4), (1, 2), (2, 3), (3, 4)])

# %%
nx.to_edgelist(G0) # there is a third coordinate (weight or label if there are some)
# Out:
# EdgeDataView([(0, 1, {}), (0, 4, {}), (1, 2, {}), (2, 3, {}), (3, 4, {})])

# %% [markdown]
# ### From an edge list to a graph (undirected)

# %%
test=[(0,1),(2,0),(4,1),(5,3),(5,0),(3,2)]

G1=nx.Graph()
G1=nx.from_edgelist(test)
nx.draw(G1, with_labels=True)

# The definition of the nodes is implicit from the edge (but we would be missing a node without edge)

# %%
# Surprisingly the graph has no orientation : we added edges.
A=nx.adjacency_matrix(G1)
print(A)
# Out:
#   (0, 1)	1
#   (0, 2)	1
#   (0, 4)	1
#   (1, 0)	1
#   (1, 3)	1
#   (2, 0)	1
#   (2, 5)	1
#   (3, 1)	1
#   (4, 0)	1
#   (4, 5)	1
#   (5, 2)	1
#   (5, 4)	1

# %% [markdown]
# ### From an edge list to a graph (directed)

# %%
# If one wants a directed graph, the key point it to say from the creation stage that we wish to obtain a directed graph
G2=nx.DiGraph() # I want a directed graph
G2.add_edges_from(test)
nx.draw(G2)

# %% [markdown]
# ### From an array to a graph (directed)

# %%
# Create from a numpy array
# Create a random matrix of size 5 by 5 with natural number between 0 and 1
A=np.random.randint(2, size=(5, 5))
print(A)
# Out:
# [[1 1 0 1 1]
#  [1 1 0 0 1]
#  [1 1 0 1 0]
#  [0 0 0 0 0]
#  [1 0 1 0 1]]

# %%
G1=nx.from_numpy_matrix(A)
nx.draw(G1,with_labels=True)

# %% [markdown]
# # 5) Creating a network edge by edge from another data structure

# %% [markdown]
# From an alternative data structure, there are two options:
# - create first the list of edges or the adjacency matrix and use the previous section,
# - directly go over the list of the data structure and add edges progressively.
#
# We present two functions doing that:
# - the first one takes as input a matrix and create the graph (we are writing our own nx.from_numpy_matrix).
# - the second one takes as input an excel file where each line has two entries representing the two extremities of a link.
#
# The idea is to parse the input (matrix or excel file) and convert each entry (coefficient of the matrix, line in the excel file) into an edge.
#
# What do we need? Loop and add_edge.

# %% [markdown]
# ## From matrix

# %%
def digraph_from_adjacency_matrix(mat): # define a new complex function taking an argument.
    # The argument will be called mat in the program independtly of the name outside. 
    # Mat ONLY exists inside the function
    
    G=nx.DiGraph()
    
    n=mat.shape[1]
    
    for i in range(n):
        for j in range(n):
            if mat[i,j]==1:
                G.add_edge(i,j)

    return G  # function return the graph G, G is also an internal name

# %%
G3=digraph_from_adjacency_matrix(A)
pos=nx.circular_layout(G3)

nx.draw(G3,pos,with_labels=True)

# %% [markdown]
# ## From an excel file

# %%
G1=nx.empty_graph(7624)

# %%
with open('lastfm_asia_edges.csv',newline='') as f:
    reader = csv.DictReader(f)
    
    for row in reader:
        a=row['node_1']
        b=row['node_2']
        G1.add_edge(int(a),int(b)) # use integer as name

# %%
nx.draw(G1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\networkx\drawing\layout.py in fruchterman_reingold_layout(G, k, pos, fixed, iterations, threshold, weight, scale, center, dim, seed)
#     485             k = dom_size / np.sqrt(nnodes)
# --> 486         pos = _sparse_fruchterman_reingold(A, k, pos_arr, fixed,
#     487                                            iterations, threshold,
#
# <decorator-gen-834> in _sparse_fruchterman_reingold(A, k, pos, fixed, iterations, threshold, dim, seed)
#
# C:\ProgramData\Anaconda3\lib\site-packages\networkx\utils\decorators.py in _random_state(func, *args, **kwargs)
#     404         new_args[random_state_index] = random_state
# --> 405         return func(*new_args, **kwargs)
#     406     return _random_state
#
# ...

# %% [markdown]
# #### This is a large graph so we can not plot it. We need to select a subgraph

# %%
lst=random.sample(range(7624),400) # Pick 300 numbers
print(lst)
# Out:
# [2287, 3704, 715, 4245, 1523, 4878, 5688, 3125, 4224, 5472, 6537, 578, 3576, 5517, 569, 4994, 699, 203, 5005, 2457, 5431, 416, 2478, 737, 2974, 875, 7097, 1287, 5767, 796, 7235, 5016, 654, 331, 5791, 7622, 2738, 3933, 1603, 6419, 4006, 5648, 3078, 682, 4841, 2743, 5398, 981, 4349, 4332, 529, 2444, 5459, 6296, 1129, 3917, 2203, 1854, 871, 6407, 881, 4988, 3189, 6280, 928, 3554, 6487, 5304, 2329, 7408, 2475, 2113, 678, 6572, 4427, 6668, 2921, 4211, 1806, 1676, 7149, 6028, 2106, 6984, 3939, 413, 1744, 1257, 2311, 3076, 1759, 4268, 4723, 1479, 7246, 3897, 711, 7293, 6716, 5923, 3733, 7599, 7134, 5876, 4205, 6650, 5541, 6088, 2122, 1752, 3366, 149, 2734, 4774, 2348, 7179, 3023, 153, 5864, 7337, 59, 4452, 287, 977, 3066, 7104, 5762, 6932, 5480, 5978, 5412, 1674, 4815, 6360, 3970, 6218, 7109, 4416, 1043, 1978, 5002, 3810, 1866, 4093, 4541, 5450, 5584, 1231, 3047, 644, 4880, 1828, 6926, 3025, 2470, 5041, 443, 2358, 1454, 2278, 247, 5462, 4033, 3868, 1246, 6198, 5466, 4133, 2732, 7614, 5073, 
# ...

# %%
G2=G1.subgraph(lst) #subgraph corresponding to these nodes

# %%
nx.draw(G2,with_labels=False,node_size=0.2)

# %%
#How could we select maybe to have a better view of the graph ?

# %% [markdown]
# # 6) Compute measures in graphs

# %% [markdown]
# We provide each time a method by hand ( with using only basic function of networkx) and the function in networkx

# %% [markdown]
# ### a) Average degree

# %%
# Other way to do it : call the list of degree and take the average
def myAverageDegree2(G):
    c=0
    N=G.number_of_nodes()
    for n in G.nodes(): # go over every node
        c=c+G.degree(n) # add the degree of node n
    
    e=c/N # normalize
    return e

# %%
k=myAverageDegree(G)
k
# Out:
# 3.5555555555555554

# %% [markdown]
# ### a) Density

# %%
d = nx.density(G)
d
# Out:
# 0.08080808080808081

# %%
#density
def myDensity(G):
    N=G.number_of_nodes()
    c=myAverageDegree2(G)/(N-1)
    return c

# Other way to do it : could call the list of edges and looking at its length

# %%
myd = myDensity(G)
myd
# Out:
# 0.0808080808080808

# %%
# Seems not to not exists in networkx
